# %%
import numpy as np
import pandas as pd
import sys
import csv
import xlrd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
sys.path.insert(0, "C:\\kt\\696\\KT\\CS696")

# %%
from edgar.stock import Stock
wb = xlrd.open_workbook('ticker_lists.xlsx')
sheet = wb.sheet_by_index(0)
stock_list=[]
for i in range(5,2956):
    stock_list.append(sheet.cell_value(i,0))

# %%
with open('Data_2018_3k.csv', mode='w' ,newline='') as file:
  file_writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  file_writer.writerow(["year",'Company',"CIK", "Revenue", "NetIncomeLoss","Payments to acquire property"])
# Out:
# 69

# %%
revenue=['us-gaap_SalesRevenueNet','us-gaap_Revenues','us-gaap:Revenues','us-gaap:SalesRevenueNet','us-gaap:RevenueFromContractWithCustomerExcludingAssessedTax']
netinc=['us-gaap:NetIncomeLoss','us-gaap_NetIncomeLoss','us-gaap:NetIncomeLoss']
rnd=['us-gaap:ResearchAndDevelopmentExpenseExcludingAcquiredInProcessCost','us-gaap_ResearchAndDevelopmentExpense']
prop=['us-gaap_PaymentsToAcquirePropertyPlantAndEquipment','us-gaap_PropertyPlantAndEquipmentNet','us-gaap_PaymentsToAcquireProductiveAssets']

# %%
stock_list[-1]
# Out:
# 'WIFI'

# %%
cik_not_found=[]
year_not_found=[]
income_statements_error=[]
balance_sheets_error=[]
cash_flows_error=[]

for y in range(2019,2020):
    for k in stock_list:
        
        try:
            stock = Stock(k)
        except:
            cik_not_found.append(k)
            continue
        period = 'quarterly'

        try:
            filing = stock.get_filing('annual',y,2)
        except:
            year_not_found.append([k,y])

        try:
          income_statements = filing.get_income_statements()
          newdict_income_statements = income_statements.reports[0]
        except:
          income_statements_error.append(k)
        try:
          balance_sheets = filing.get_balance_sheets()
          newdict_balance_sheets = balance_sheets.reports[0]
        
        

       
        #print(type(income_statements),type(cash_flows))
        
            
        except:
            

            balance_sheets_error.append(k)
        try:
            cash_flows = filing.get_cash_flows()
            newdict_cash_flows = cash_flows.reports[0]
        except:
            cash_flows_error.append(k)
#         print("\n\n",income_statements)
#         print("\n\n",cash_flows)
        #print(newdict_balance_sheets.map.keys())
        with open('Data_2018_3k.csv', mode='a',newline='') as file:
            file_writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
            if income_statements:
                    print(income_statements)
                    print(newdict_income_statements.map.keys())
                    rev=0
                    rnd='tag not found'
                    for i in revenue:
                          if i in newdict_income_statements.map.keys():
                              
                              rev=newdict_income_statements.map[i].value
                          

                    for m in newdict_income_statements.map.keys():
                          if m in rnd:
                              rnd=newdict_income_statements.map[m].value
                          
                      
                        
              
            else:
                rev='Income statement not found'
                rnd='Income statement not found'
            if cash_flows:
                    netincome=0
                    paymentProp='tag not found'
                    for j in netinc:
                        if j in newdict_cash_flows.map.keys():
                        #print(i)
                            netincome=newdict_cash_flows.map[j].value
                       

              
                    for p in prop:
                        if p in newdict_cash_flows.map.keys():
                            paymentProp=newdict_cash_flows.map[p].value
                       
                            
                        
                      
               
            else:
                netincome='cash flow not found'
                paymentProp='cash flow not found'

            file_writer.writerow([y-1,k,stock.cik, rev,netincome,paymentProp])
# Out:
# cik for AAXN is 1069183
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR2/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1069183/0001069183-19-000066.txt
# C:\kt\696\KT\CS696\edgar\document_text.py:27: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 27 of the file C:\kt\696\KT\CS696\edgar\document_text.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   value = BeautifulSoup(value)
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# <report instance="aaxn-20190331.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Condensed Consolidated Balance Sheets (Unaudited)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://axon.com/role/CondensedConsolidatedBalanceSheetsUnaudited</role>
# <shortname>Condensed Consolidated Balance Sheets (Unaudited)</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for condensed consolidated balance sheets (unaudited) (filename: R2.htm)
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 86
# cik for AIR is 1750
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR2/master.idx
# No quarterly filing info found for year=2019 quarter=2. Finding latest.
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR2/master.idx
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# <report instance="aaxn-20190331.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Condensed Consolidated Balance Sheets (Unaudited)</longname>
# <reporttype>Sheet</reporttype>
# <role>http://axon.com/role/CondensedConsolidatedBalanceSheetsUnaudited</role>
# <shortname>Condensed Consolidated Balance Sheets (Unaudited)</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for condensed consolidated balance sheets (unaudited) (filename: R2.htm)
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 82
# cik for AJRD is 40888
# getting ['10-Q', '10-Q/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR2/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/40888/0000040888-19-000015.txt

# %%
cik_not_found
# Out:
# ['Ticker',
#  'BRK.B',
#  'LIN',
#  'BKNG',
#  'TFC',
#  'LHX',
#  'DOW',
#  'UBER',
#  'WELL',
#  'IQV',
#  'CTVA',
#  'APTV',
#  'CBRE',
#  'FRC',
#  'VIAC',
#  'PEAK',
#  'CCL.U',
#  'SPOT',
#  'EVRG',
#  'BKR',
#  'J',
#  'DOCU',
#  'ELAN',
#  'VICI',
#  'BF.B',
#  'GL',
#  'WTRG',
#  'EQH',
#  'NLOK',
#  'BKI',
#  'LYFT',
#  'EHC',
#  'SBNY',
#  'DELL',
#  'GLIBA',
#  'CDAY',
#  'COLD',
#  'IAA',
#  'JEF',
#  'AVTR',
#  'KDP',
#  'WH',
#  'NWSA',
#  'BYND',
#  'PLAN',
#  'KMPR',
#  'CPRI',
#  'WYND',
#  'SMAR',
#  'NVST',
#  'AVLR',
#  'NVT',
#  'UAA',
#  'DBX',
#  'SVC',
#  'ZS',
#  'FTDR',
#  'OZK',
#  'QRTEA',
#  'ESTC',
#  'GH',
#  'ESI',
#  'STAY.U',
#  'CLNY',
#  'APY',
#  'ETRN',
#  'DT',
#  'JW.A',
#  'SITC',
#  'GO',
#  'UI',
#  'REZI',
#  'CVET',
#  'BPR',
#  'PS',
#  'FWONA',
#  'PD',
#  'SWI',
#  'CHNG',
#  'ADT',
#  'CRNC',
#  'EAF',
#  'GTES',
#  'ADPT',
#  'LGF.A',
#  'MDLA']

# %%
year_not_found
# Out:
# [['GOOGL', 2013],
#  ['MDT', 2013],
#  ['PYPL', 2013],
#  ['AVGO', 2013],
#  ['AGN', 2013],
#  ['ICE', 2013],
#  ['BAX', 2013],
#  ['WBA', 2013],
#  ['INFO', 2013],
#  ['HLT', 2013],
#  ['SQ', 2013],
#  ['TWTR', 2013],
#  ['SPLK', 2013],
#  ['FTV', 2013],
#  ['SYF', 2013],
#  ['VEEV', 2013],
#  ['HPE', 2013],
#  ['KHC', 2013],
#  ['KEYS', 2013],
#  ['TEAM', 2013],
#  ['CFG', 2013],
#  ['INVH', 2013],
#  ['YUMC', 2013],
#  ['PAYC', 2013],
#  ['TWLO', 2013],
#  ['RNG', 2013],
#  ['BURL', 2013],
#  ['LBRDK', 2013],
#  ['ANET', 2013],
#  ['OKTA', 2013],
#  ['LW', 2013],
#  ['QRVO', 2013],
#  ['STE', 2013],
#  ['ALLE', 2013],
#  ['MYL', 2013],
#  ['GDDY', 2013],
#  ['TTD', 2013],
#  ['ROKU', 2013],
#  ['WRK', 2013],
#  ['ARMK', 2013],
#  ['DOX', 2013],
#  ['COUP', 2013],
#  ['ZEN', 2013],
#  ['GLPI', 2013],
#  ['VST', 2013],
#  ['DXC', 2013],
#  ['USFD', 2013],
#  ['CTLT', 2013],
#  ['STOR', 2013],
#  ['VOYA', 2013],
#  ['ATUS', 2013],
#  ['ZAYO', 2013],
#  ['QGEN', 2013],
#  ['CABO', 2013],
#  ['PRGO', 2013],
#  ['HUBS', 2013],
#  ['AMH', 2013],
#  ['HDS', 2013],
#  ['NRZ', 2013],
#  ['MDB', 2013],
#  ['PRAH', 2013],
#  ['PLNT', 2013],
#  ['ATH', 2013],
#  ['CDK', 2013],
#  ['ARW', 2013],
#  ['BRX', 2013],
#  ['W', 2013],
#  ['AXTA', 2013],
#  ['SABR', 2013],
#  ['AYX', 2013],
#  ['Z', 2013],
#  ['NTNX', 2013],
#  ['ETSY', 2013],
#  ['PEN', 2013],
#  ['PK', 2013],
#  ['MSG', 2013],
#  ['PE', 2013],
#  ['BLUE', 2013],
#  ['GRUB', 2013],
#  ['JBGS', 2013],
#  ['SERV', 2013],
#  ['GDI', 2013],
#  ['ASH', 2013],
#  ['PCTY', 2013],
#  ['BHF', 2013],
#  ['OUT', 2013],
#  ['PSTG', 2013],
#  ['VVV', 2013],
#  ['JHG', 2013],
#  ['MTCH', 2013],
#  ['CVNA', 2013],
#  ['FHB', 2013],
#  ['UNVR', 2013],
#  ['FND', 2013],
#  ['SAGE', 2013],
#  ['COTY', 2013],
#  ['CPA', 2013],
#  ['ENR', 2013],
#  ['FEYE', 2013],
#  ['NEWR', 2013],
#  ['AGIO', 2013],
#  ['AGR', 2013],
#  ['AA', 2013],
#  ['OLLI', 2013],
#  ['OMF', 2013],
#  ['PGRE', 2013],
#  ['HGV', 2013],
#  ['NAVI', 2013],
#  ['SC', 2013],
#  ['CC', 2013],
#  ['COMM', 2013],
#  ['ESRT', 2013],
#  ['PINC', 2013],
#  ['SFM', 2013],
#  ['PAG', 2013],
#  ['IGT', 2013],
#  ['AM', 2013],
#  ['SNDR', 2013],
#  ['TWOU', 2013],
#  ['SWCH', 2013],
#  ['VIRT', 2013],
#  ['CDEV', 2013],
#  ['AR', 2013],
#  ['ARD', 2013]]

# %%
income_statements_error
# Out:
# ['MSFT',
#  'JNJ',
#  'PG',
#  'MA',
#  'BAC',
#  'XOM',
#  'HD',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'BMY',
#  'COST',
#  'ACN',
#  'TMO',
#  'PM',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'LMT',
#  'SBUX',
#  'DHR',
#  'LOW',
#  'MMM',
#  'FIS',
#  'MO',
#  'MDLZ',
#  'CHTR',
#  'USB',
#  'GS',
#  'ADP',
#  'SYK',
#  'CB',
#  'UPS',
#  'CAT',
#  'PNC',
#  'ZTS',
#  'COP',
#  'NOW',
#  'AGN',
#  'CCI',
#  'GPN',
#  'CSX',
#  'NOC',
#  'APD',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'PGR',
#  'SHW',
#  'EXC',
#  'GD',
#  'EMR',
#  'AIG',
#  'EOG',
#  'EL',
#  'GM',
#  'SPG',
#  'ROST',
#  'PSX',
#  'DG',
#  'HCA',
#  'DD',
#  'ROP',
#  'AFL',
#  'BK',
#  'NEM',
#  'FDX',
#  'SYY',
#  'TRV',
#  'IR',
#  'PSA',
#  'F',
#  'HPQ',
#  'INFO',
#  'WEC',
#  'HLT',
#  'GIS',
#  'STZ',
#  'ED',
#  'REGN',
#  'AVB',
#  'PPG',
#  'STT',
#  'LULU',
#  'EBAY',
#  'PAYX',
#  'FE',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'DLR',
#  'ADM',
#  'TMUS',
#  'BLL',
#  'AWK',
#  'CTAS',
#  'ROK',
#  'PANW',
#  'MTB',
#  'AME',
#  'LYB',
#  'KR',
#  'VRSN',
#  'CMG',
#  'FAST',
#  'WY',
#  'DLTR',
#  'CLX',
#  'CDNS',
#  'SWKS',
#  'RCL',
#  'AEE',
#  'BBY',
#  'NTRS',
#  'DHI',
#  'MKC',
#  'VEEV',
#  'VMC',
#  'HPE',
#  'UAL',
#  'LEN',
#  'TFX',
#  'TRU',
#  'IAC',
#  'IP',
#  'MLM',
#  'DOV',
#  'TEAM',
#  'K',
#  'MKL',
#  'CINF',
#  'TIF',
#  'KMX',
#  'YUMC',
#  'HES',
#  'CAG',
#  'ULTA',
#  'XYL',
#  'TWLO',
#  'CAH',
#  'IFF',
#  'NUE',
#  'DRI',
#  'NLY',
#  'SSNC',
#  'LBRDK',
#  'UDR',
#  'GPC',
#  'BR',
#  'CBOE',
#  'ANET',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'SGEN',
#  'AMTD',
#  'CNP',
#  'EXAS',
#  'ODFL',
#  'ZBRA',
#  'ALNY',
#  'VAR',
#  'STE',
#  'TYL',
#  'EXPD',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'EPAM',
#  'RJF',
#  'SJM',
#  'MYL',
#  'NCLH',
#  'WST',
#  'FICO',
#  'LNC',
#  'Y',
#  'RE',
#  'NI',
#  'APA',
#  'HII',
#  'ROKU',
#  'BAH',
#  'WRK',
#  'CPT',
#  'AGNC',
#  'EMN',
#  'VER',
#  'DOX',
#  'ETFC',
#  'DISH',
#  'CHRW',
#  'SIRI',
#  'RPM',
#  'PKG',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'NNN',
#  'JBHT',
#  'RGA',
#  'NBIX',
#  'CSL',
#  'GGG',
#  'JLL',
#  'DVN',
#  'SNA',
#  'TTC',
#  'USFD',
#  'ON',
#  'SRPT',
#  'XPO',
#  'STOR',
#  'VOYA',
#  'ATUS',
#  'SCI',
#  'MASI',
#  'CPB',
#  'CZR',
#  'LAMR',
#  'HUBB',
#  'MPWR',
#  'TECH',
#  'GNTX',
#  'FFIV',
#  'CHE',
#  'PNR',
#  'PRGO',
#  'MOS',
#  'RGLD',
#  'HRC',
#  'BWA',
#  'CONE',
#  'DCI',
#  'OC',
#  'PVH',
#  'ATH',
#  'HZNP',
#  'WWD',
#  'FIVE',
#  'CW',
#  'MIDD',
#  'ACC',
#  'ITT',
#  'MKSI',
#  'CUZ',
#  'COG',
#  'CASY',
#  'BERY',
#  'ETSY',
#  'WSM',
#  'IDA',
#  'HOG',
#  'PRI',
#  'NYCB',
#  'ALSN',
#  'BRKR',
#  'AWI',
#  'HHC',
#  'HRB',
#  'PNFP',
#  'KEX',
#  'XEC',
#  'COR',
#  'THO',
#  'JWN',
#  'PSTG',
#  'PACW',
#  'VVV',
#  'TWO',
#  'JHG',
#  'STL',
#  'LOGM',
#  'CIM',
#  'RYN',
#  'UNVR',
#  'LOPE',
#  'IBKR',
#  'EXP',
#  'WRI',
#  'NFG',
#  'WTM',
#  'MIC',
#  'CPA',
#  'ASB',
#  'PBF',
#  'VMI',
#  'TRIP',
#  'ALKS',
#  'SIX',
#  'BOKF',
#  'RPAI',
#  'R',
#  'S',
#  'AN',
#  'TDS',
#  'CMD',
#  'OI',
#  'WWE',
#  'UFS',
#  'TCO',
#  'SATS',
#  'PINC',
#  'EQT',
#  'IGT',
#  'TFSL',
#  'SEB',
#  'SWCH',
#  'VIRT',
#  'USM',
#  'AR',
#  'ARD']

# %%
balance_sheets_error
# Out:
# ['MSFT',
#  'MA',
#  'BAC',
#  'XOM',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'BA',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'ABT',
#  'TMO',
#  'NEE',
#  'UNP',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'MMM',
#  'USB',
#  'GS',
#  'CI',
#  'CAT',
#  'SO',
#  'PNC',
#  'ZTS',
#  'COP',
#  'BLK',
#  'MS',
#  'CCI',
#  'GPN',
#  'ITW',
#  'NOC',
#  'TGT',
#  'AON',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'EXC',
#  'AIG',
#  'GM',
#  'PSX',
#  'KMI',
#  'ALL',
#  'PRU',
#  'BK',
#  'FDX',
#  'CTSH',
#  'TRV',
#  'PSA',
#  'F',
#  'GIS',
#  'ED',
#  'PPG',
#  'STT',
#  'EBAY',
#  'WLTW',
#  'PAYX',
#  'FE',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'DTE',
#  'CTAS',
#  'MSCI',
#  'DFS',
#  'ROK',
#  'IDXX',
#  'PANW',
#  'MTB',
#  'AME',
#  'CMG',
#  'WY',
#  'SWKS',
#  'AEE',
#  'NTRS',
#  'MKC',
#  'VEEV',
#  'AJG',
#  'TRU',
#  'IAC',
#  'IP',
#  'K',
#  'HES',
#  'CAG',
#  'ULTA',
#  'PFG',
#  'IFF',
#  'HBAN',
#  'DRI',
#  'GRMN',
#  'NLY',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'AMTD',
#  'EXAS',
#  'ODFL',
#  'HRL',
#  'TYL',
#  'MKTX',
#  'ELS',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'RJF',
#  'NCLH',
#  'WST',
#  'VMW',
#  'APA',
#  'HII',
#  'ROKU',
#  'BAH',
#  'WRK',
#  'EMN',
#  'CCK',
#  'ETFC',
#  'RPM',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'RGA',
#  'ON',
#  'SCI',
#  'AFG',
#  'HUBB',
#  'KIM',
#  'MPWR',
#  'GNTX',
#  'LPLA',
#  'CHE',
#  'MOS',
#  'BWA',
#  'PBCT',
#  'RHI',
#  'SPR',
#  'CONE',
#  'TCF',
#  'HFC',
#  'FIVE',
#  'CW',
#  'COG',
#  'BERY',
#  'ETSY',
#  'WSM',
#  'IDA',
#  'BPOP',
#  'ROL',
#  'NYCB',
#  'FHN',
#  'PNFP',
#  'LAZ',
#  'STL',
#  'LOGM',
#  'ERIE',
#  'FHB',
#  'CIM',
#  'IBKR',
#  'ICUI',
#  'WTFC',
#  'BOH',
#  'GRA',
#  'RBC',
#  'MIC',
#  'CPA',
#  'SCCO',
#  'PBF',
#  'EVR',
#  'FLR',
#  'BOKF',
#  'SPB',
#  'TDS',
#  'TCO',
#  'BGCP',
#  'PAG',
#  'TFSL',
#  'ANAT',
#  'USM',
#  'AR',
#  'ARD']

# %%
cash_flows_error
# Out:
# ['MSFT',
#  'MA',
#  'BAC',
#  'XOM',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'ABT',
#  'IBM',
#  'ACN',
#  'TMO',
#  'NEE',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'MMM',
#  'GILD',
#  'USB',
#  'ADP',
#  'UPS',
#  'CAT',
#  'SO',
#  'D',
#  'PNC',
#  'ZTS',
#  'COP',
#  'CCI',
#  'GPN',
#  'ITW',
#  'CSX',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'SHW',
#  'EXC',
#  'AIG',
#  'PSX',
#  'KMI',
#  'BK',
#  'NEM',
#  'FDX',
#  'SYY',
#  'TRV',
#  'PSA',
#  'F',
#  'GIS',
#  'ED',
#  'APH',
#  'PPG',
#  'ES',
#  'STT',
#  'EBAY',
#  'PAYX',
#  'FE',
#  'FLT',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'CTAS',
#  'ROK',
#  'IDXX',
#  'PANW',
#  'MTB',
#  'AME',
#  'LYB',
#  'ALXN',
#  'CMG',
#  'WY',
#  'SWKS',
#  'AEE',
#  'NTRS',
#  'MKC',
#  'VEEV',
#  'VMC',
#  'HPE',
#  'AJG',
#  'UAL',
#  'CHD',
#  'TRU',
#  'IAC',
#  'ACGL',
#  'IP',
#  'MLM',
#  'K',
#  'HES',
#  'CAG',
#  'ULTA',
#  'XYL',
#  'TWLO',
#  'IFF',
#  'DRI',
#  'NLY',
#  'UDR',
#  'CBOE',
#  'ANET',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'AMTD',
#  'CNP',
#  'EXAS',
#  'ODFL',
#  'FNF',
#  'TYL',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'SJM',
#  'MYL',
#  'NCLH',
#  'WST',
#  'VNO',
#  'NI',
#  'BRO',
#  'APA',
#  'BAH',
#  'WRK',
#  'VER',
#  'DOX',
#  'CCK',
#  'ETFC',
#  'RPM',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'RGA',
#  'SNA',
#  'ON',
#  'XPO',
#  'STOR',
#  'VOYA',
#  'ATUS',
#  'SCI',
#  'AIZ',
#  'AFG',
#  'DVA',
#  'HUBB',
#  'KIM',
#  'MPWR',
#  'GNTX',
#  'CHE',
#  'MOS',
#  'HRC',
#  'BWA',
#  'CONE',
#  'HFC',
#  'FIVE',
#  'AOS',
#  'COG',
#  'BERY',
#  'ETSY',
#  'LB',
#  'NYT',
#  'WAL',
#  'PRI',
#  'HHC',
#  'PNFP',
#  'COR',
#  'STL',
#  'LOGM',
#  'UMPQ',
#  'WTM',
#  'RBC',
#  'MIC',
#  'CPA',
#  'SCCO',
#  'ASB',
#  'PBF',
#  'TRIP',
#  'SIX',
#  'COLM',
#  'OMF',
#  'PGRE',
#  'BDN',
#  'HGV',
#  'FLR',
#  'BOKF',
#  'TDS',
#  'OI',
#  'UFS',
#  'TCO',
#  'EQT',
#  'IGT',
#  'SEB',
#  'SWCH',
#  'VIRT',
#  'USM',
#  'AR',
#  'ARD']

# %%
# cash_flows.reports[1]

# %%
# cash_flows.reports[0]
