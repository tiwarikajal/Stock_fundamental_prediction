# %%
import numpy as np
import pandas as pd
import sys
import csv
import xlrd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
sys.path.insert(0, r"C:\Umass spring 20\696\KT\CS696")

# %%
from edgar.stock import Stock
wb = xlrd.open_workbook('ticker_lists.xlsx')
sheet = wb.sheet_by_index(0) 
stock_list=[]
for i in range(4,985):
    stock_list.append(sheet.cell_value(i,0))

# %%
with open('Data_2018.csv', mode='w' ,newline='') as file:
  file_writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  file_writer.writerow(["year",'Company',"CIK", "Revenue", "NetIncomeLoss","Payments to acquire property"])
# Out:
# 69

# %%
revenue=['us-gaap_SalesRevenueNet','us-gaap_Revenues','us-gaap:Revenues','us-gaap:SalesRevenueNet','us-gaap:RevenueFromContractWithCustomerExcludingAssessedTax']
netinc=['us-gaap:NetIncomeLoss','us-gaap_NetIncomeLoss','us-gaap:NetIncomeLoss']
rnd=['us-gaap:ResearchAndDevelopmentExpenseExcludingAcquiredInProcessCost','us-gaap_ResearchAndDevelopmentExpense']
prop=['us-gaap_PaymentsToAcquirePropertyPlantAndEquipment','us-gaap_PropertyPlantAndEquipmentNet','us-gaap_PaymentsToAcquireProductiveAssets']

# %%
cik_not_found=[]
year_not_found=[]
income_statements_error=[]
balance_sheets_error=[]
cash_flows_error=[]

for y in range(2019,2020):
    for k in stock_list:
        rev='tag not found'
        rnd='tag not found'
        netincome='tag not found'
        paymentProp='tag not found'
        try:
            stock = Stock(k)
        except:
            cik_not_found.append(k)
            continue
        period = 'annual'

        try:
            filing = stock.get_filing('annual',y,1)
        except:
            year_not_found.append([k,y])

        try:
          income_statements = filing.get_income_statements()
          newdict_income_statements = income_statements.reports[0]
        except:
          income_statements_error.append(k)
        try:
          balance_sheets = filing.get_balance_sheets()
          newdict_balance_sheets = balance_sheets.reports[0]
        
        

       
        #print(type(income_statements),type(cash_flows))
        
            
        except:
            

            balance_sheets_error.append(k)
        try:
            cash_flows = filing.get_cash_flows()
            newdict_cash_flows = cash_flows.reports[0]
        except:
            cash_flows_error.append(k)
#         print("\n\n",income_statements)
#         print("\n\n",cash_flows)
        #print(newdict_balance_sheets.map.keys())
        with open('Data_2018.csv', mode='a',newline='') as file:
            file_writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
            if income_statements:
#                     print(income_statements)
#                     print(newdict_income_statements.map.keys())
                    
                    for i in revenue:
                          if i in newdict_income_statements.map.keys():
                              
                              rev=newdict_income_statements.map[i].value
                          

                    for m in newdict_income_statements.map.keys():
                          if m in rnd:
                              rnd=newdict_income_statements.map[m].value
                          
                      
                        
              
            else:
                rev='Income statement not found'
                rnd='Income statement not found'
            if cash_flows:
                    
                    for j in netinc:
                        if j in newdict_cash_flows.map.keys():
                        #print(i)
                            netincome=newdict_cash_flows.map[j].value
                       

              
                    for p in prop:
                        if p in newdict_cash_flows.map.keys():
                            paymentProp=newdict_cash_flows.map[p].value
                       
                            
                        
                      
               
            else:
                netincome='cash flow not found'
                paymentProp='cash flow not found'

            file_writer.writerow([y-1,k,stock.cik, rev,netincome,paymentProp])
# Out:
# cik for AAPL is 320193
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# No annual filing info found for year=2019 quarter=1. Finding latest.
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/320193/0000320193-18-000145.txt
# C:\Umass spring 20\696\KT\CS696\edgar\document_text.py:27: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 27 of the file C:\Umass spring 20\696\KT\CS696\edgar\document_text.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   value = BeautifulSoup(value)
# could not find anything for ShortName consolidated statements of income
# <report instance="aapl-20180929.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - CONSOLIDATED STATEMENTS OF OPERATIONS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.apple.com/role/ConsolidatedStatementsOfOperations</role>
# <shortname>CONSOLIDATED STATEMENTS OF OPERATIONS</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of operations (filename: R2.htm)
# <report instance="aapl-20180929.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R5.htm</htmlfilename>
# <longname>1003000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.apple.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>5</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R5.htm)
# <report instance="aapl-20180929.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R9.htm</htmlfilename>
# <longname>1005000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.apple.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>9</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R9.htm)
# 62
# cik for MSFT is 789019
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# No annual filing info found for year=2019 quarter=1. Finding latest.
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR3/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/789019/0001564590-18-019062.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 85
# cik for AMZN is 1018724
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1018724/0001018724-19-000004.txt
# could not find anything for ShortName consolidated statements of income
# <report instance="amzn-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R3.htm</htmlfilename>
# <longname>1002000 - Statement - Consolidated Statements Of Operations</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.amazon.com/role/ConsolidatedStatementsOfOperations</role>
# <shortname>Consolidated Statements Of Operations</shortname>
# <menucategory>Statements</menucategory>
# <position>3</position>
# </report>
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of operations (filename: R3.htm)
# <report instance="amzn-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1004000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.amazon.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R6.htm)
# <report instance="amzn-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.amazon.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R2.htm)
# 62
# cik for FB is 1326801
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1326801/0001326801-19-000009.txt
# <report instance="fb-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1002000 - Statement - CONSOLIDATED STATEMENTS OF INCOME</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.facebook.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>CONSOLIDATED STATEMENTS OF INCOME</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R4.htm)
# <report instance="fb-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.facebook.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="fb-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R7.htm</htmlfilename>
# <longname>1005000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.facebook.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>7</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R7.htm)
# 60
# cik for GOOGL is 1652044
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1652044/0001652044-19-000004.txt
# <report instance="goog-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1002000 - Statement - CONSOLIDATED STATEMENTS OF INCOME</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.google.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>CONSOLIDATED STATEMENTS OF INCOME</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R4.htm)
# <report instance="goog-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.google.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="goog-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R8.htm</htmlfilename>
# <longname>1005000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.google.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>8</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R8.htm)
# 63
# cik for JPM is 19617
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/19617/0000019617-19-000054.txt
# <report instance="corp10k2018.htm">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Statements of Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.jpmorganchase.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>Consolidated Statements of Income</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R2.htm)
# <report instance="corp10k2018.htm">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1003000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.jpmorganchase.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R4.htm)
# <report instance="corp10k2018.htm">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R8.htm</htmlfilename>
# <longname>1005000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.jpmorganchase.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>8</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R8.htm)
# Warning:  (from us-gaap_ProceedsFromShortTermDebt) is not numeric even after removing special characters () - ignoring
# 58
# cik for JNJ is 200406
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/200406/0000200406-19-000009.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# <report instance="jnj-20181230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.jnj.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="jnj-20181230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R9.htm</htmlfilename>
# <longname>1005000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.jnj.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>9</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R9.htm)
# 72
# cik for V is 1403161
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# No annual filing info found for year=2019 quarter=1. Finding latest.
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1403161/0001403161-18-000055.txt
# could not find anything for ShortName consolidated statements of income
# <report instance="v-20180930.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1002000 - Statement - CONSOLIDATED STATEMENTS OF OPERATIONS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://wwww.visa.com/role/ConsolidatedStatementsOfOperations</role>
# <shortname>CONSOLIDATED STATEMENTS OF OPERATIONS</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of operations (filename: R4.htm)
# <report instance="v-20180930.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://wwww.visa.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="v-20180930.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R8.htm</htmlfilename>
# <longname>1005000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://wwww.visa.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>8</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R8.htm)
# 57
# cik for PG is 80424
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# No annual filing info found for year=2019 quarter=1. Finding latest.
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR3/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/80424/0000080424-18-000055.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# <report instance="fy171810-kreport.htm">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R5.htm</htmlfilename>
# <longname>1004000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.pg.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>5</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R5.htm)
# <report instance="fy171810-kreport.htm">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R9.htm</htmlfilename>
# <longname>1006000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.pg.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>9</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R9.htm)
# 70
# cik for INTC is 50863
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/50863/0000050863-19-000007.txt
# <report instance="intc-20181229.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Statements of Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.intel.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>Consolidated Statements of Income</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R2.htm)
# <report instance="intc-20181229.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1003000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.intel.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R4.htm)
# <report instance="intc-20181229.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1004000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.intel.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R6.htm)
# 60
# cik for MA is 1141391
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/1141391/0001141391-19-000013.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 84
# cik for BAC is 70858
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/70858/0000070858-19-000012.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 83
# cik for UNH is 731766
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/731766/0000731766-19-000005.txt
# could not find anything for ShortName consolidated statements of income
# <report instance="unh-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1003000 - Statement - Consolidated Statements of Operations</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.uhc.com/role/ConsolidatedStatementsOfOperations</role>
# <shortname>Consolidated Statements of Operations</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of operations (filename: R4.htm)
# <report instance="unh-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.uhc.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="unh-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R8.htm</htmlfilename>
# <longname>1007000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.uhc.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>8</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R8.htm)
# 60
# cik for T is 732717
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/732717/0001193125-19-045608.txt
# <report instance="t-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>000100 - Statement - Consolidated Statements Of Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://att.com/role/StatementConsolidatedStatementsOfIncome</role>
# <shortname>Consolidated Statements Of Income</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# ...
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R7.htm)
# Warning:  (from us-gaap_IncreaseDecreaseInAccountsReceivableRelatedParties) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_IncreaseDecreaseInOtherNoncurrentLiabilities) is not numeric even after removing special characters () - ignoring
# 58
# cik for PPL is 922224
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/922224/0000922224-19-000015.txt
# <report instance="ppl-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - CONSOLIDATED STATEMENTS OF INCOME</longname>
# <reporttype>Sheet</reporttype>
# <role>http://pplweb.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>CONSOLIDATED STATEMENTS OF INCOME</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R2.htm)
# <report instance="ppl-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1004000 - Statement - CONSOLIDATED BALANCE SHEETS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://pplweb.com/role/ConsolidatedBalanceSheets</role>
# <shortname>CONSOLIDATED BALANCE SHEETS</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R6.htm)
# <report instance="ppl-20181231.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R5.htm</htmlfilename>
# <longname>1003000 - Statement - CONSOLIDATED STATEMENTS OF CASH FLOWS</longname>
# <reporttype>Sheet</reporttype>
# <role>http://pplweb.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>CONSOLIDATED STATEMENTS OF CASH FLOWS</shortname>
# <menucategory>Statements</menucategory>
# <position>5</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R5.htm)
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# Warning:  (from us-gaap_CashAndCashEquivalentsAtCarryingValue) is not numeric even after removing special characters () - ignoring
# 57
# cik for WMB is 107263
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/107263/0000107263-19-000007.txt
# could not find anything for ShortName consolidated statements of income
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated balance sheets
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# could not find anything for ShortName consolidated statements of cash flows
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# No financial documents could be found. Likely need to             update constants in edgar.filing.Statements.
# 84
# cik for VFC is 103379
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# No annual filing info found for year=2019 quarter=1. Finding latest.
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Will do a final attempt to find filing info from last year
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR4/master.idx
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR3/master.idx
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR2/master.idx
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2018/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/103379/0000103379-18-000003.txt
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1002000 - Statement - Consolidated Statements of Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>Consolidated Statements of Income</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R4.htm)
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1004000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R6.htm)
# 70
# cik for ETR is 65984
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx
# Processing SGML at https://www.sec.gov/Archives/edgar/data/65984/0000065984-19-000082.txt
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R4.htm</htmlfilename>
# <longname>1002000 - Statement - Consolidated Statements of Income</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedStatementsOfIncome</role>
# <shortname>Consolidated Statements of Income</shortname>
# <menucategory>Statements</menucategory>
# <position>4</position>
# </report>
# could not find anything for ShortName consolidated statements of operations
# could not find anything for ShortName consolidated statement of earnings
# could not find anything for ShortName condensed consolidated statements of income (unaudited)
# could not find anything for ShortName condensed consolidated statements of income
# could not find anything for ShortName condensed consolidated statements of operations (unaudited)
# could not find anything for ShortName condensed consolidated statements of operations
# could not find anything for ShortName condensed consolidated statement of earnings (unaudited)
# could not find anything for ShortName condensed consolidated statement of earnings
# could not find anything for ShortName condensed statements of income
# could not find anything for ShortName condensed statements of operations
# could not find anything for ShortName condensed statements of operations and comprehensive loss
# Getting financial data for consolidated statements of income (filename: R4.htm)
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R2.htm</htmlfilename>
# <longname>1001000 - Statement - Consolidated Balance Sheets</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedBalanceSheets</role>
# <shortname>Consolidated Balance Sheets</shortname>
# <menucategory>Statements</menucategory>
# <position>2</position>
# </report>
# could not find anything for ShortName consolidated statement of financial position
# could not find anything for ShortName condensed consolidated statement of financial position (current period unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position (unaudited)
# could not find anything for ShortName condensed consolidated statement of financial position
# could not find anything for ShortName condensed consolidated balance sheets (current period unaudited)
# could not find anything for ShortName condensed consolidated balance sheets (unaudited)
# could not find anything for ShortName condensed consolidated balance sheets
# could not find anything for ShortName condensed balance sheets
# Getting financial data for consolidated balance sheets (filename: R2.htm)
# <report instance="vfc-20171230.xml">
# <isdefault>false</isdefault>
# <hasembeddedreports>false</hasembeddedreports>
# <htmlfilename>R6.htm</htmlfilename>
# <longname>1004000 - Statement - Consolidated Statements of Cash Flows</longname>
# <reporttype>Sheet</reporttype>
# <role>http://www.vfc.com/role/ConsolidatedStatementsOfCashFlows</role>
# <shortname>Consolidated Statements of Cash Flows</shortname>
# <menucategory>Statements</menucategory>
# <position>6</position>
# </report>
# could not find anything for ShortName condensed consolidated statements of cash flows (unaudited)
# could not find anything for ShortName condensed consolidated statements of cash flows
# could not find anything for ShortName condensed statements of cash flows
# Getting financial data for consolidated statements of cash flows (filename: R6.htm)
# 69
# cik for DLR is 1297996
# getting ['10-K', '10-K/A'] filing info from https://www.sec.gov/Archives/edgar/full-index/2019/QTR1/master.idx

# %%
cik_not_found
# Out:
# ['Ticker',
#  'BRK.B',
#  'LIN',
#  'BKNG',
#  'TFC',
#  'LHX',
#  'DOW',
#  'UBER',
#  'WELL',
#  'IQV',
#  'CTVA',
#  'APTV',
#  'CBRE',
#  'FRC',
#  'VIAC',
#  'PEAK',
#  'CCL.U',
#  'SPOT',
#  'EVRG',
#  'BKR',
#  'J',
#  'DOCU',
#  'ELAN',
#  'VICI',
#  'BF.B',
#  'GL',
#  'WTRG',
#  'EQH',
#  'NLOK',
#  'BKI',
#  'LYFT',
#  'EHC',
#  'SBNY',
#  'DELL',
#  'GLIBA',
#  'CDAY',
#  'COLD',
#  'IAA',
#  'JEF',
#  'AVTR',
#  'KDP',
#  'WH',
#  'NWSA',
#  'BYND',
#  'PLAN',
#  'KMPR',
#  'CPRI',
#  'WYND',
#  'SMAR',
#  'NVST',
#  'AVLR',
#  'NVT',
#  'UAA',
#  'DBX',
#  'SVC',
#  'ZS',
#  'FTDR',
#  'OZK',
#  'QRTEA',
#  'ESTC',
#  'GH',
#  'ESI',
#  'STAY.U',
#  'CLNY',
#  'APY',
#  'ETRN',
#  'DT',
#  'JW.A',
#  'SITC',
#  'GO',
#  'UI',
#  'REZI',
#  'CVET',
#  'BPR',
#  'PS',
#  'FWONA',
#  'PD',
#  'SWI',
#  'CHNG',
#  'ADT',
#  'CRNC',
#  'EAF',
#  'GTES',
#  'ADPT',
#  'LGF.A',
#  'MDLA']

# %%
year_not_found
# Out:
# [['GOOGL', 2013],
#  ['MDT', 2013],
#  ['PYPL', 2013],
#  ['AVGO', 2013],
#  ['AGN', 2013],
#  ['ICE', 2013],
#  ['BAX', 2013],
#  ['WBA', 2013],
#  ['INFO', 2013],
#  ['HLT', 2013],
#  ['SQ', 2013],
#  ['TWTR', 2013],
#  ['SPLK', 2013],
#  ['FTV', 2013],
#  ['SYF', 2013],
#  ['VEEV', 2013],
#  ['HPE', 2013],
#  ['KHC', 2013],
#  ['KEYS', 2013],
#  ['TEAM', 2013],
#  ['CFG', 2013],
#  ['INVH', 2013],
#  ['YUMC', 2013],
#  ['PAYC', 2013],
#  ['TWLO', 2013],
#  ['RNG', 2013],
#  ['BURL', 2013],
#  ['LBRDK', 2013],
#  ['ANET', 2013],
#  ['OKTA', 2013],
#  ['LW', 2013],
#  ['QRVO', 2013],
#  ['STE', 2013],
#  ['ALLE', 2013],
#  ['MYL', 2013],
#  ['GDDY', 2013],
#  ['TTD', 2013],
#  ['ROKU', 2013],
#  ['WRK', 2013],
#  ['ARMK', 2013],
#  ['DOX', 2013],
#  ['COUP', 2013],
#  ['ZEN', 2013],
#  ['GLPI', 2013],
#  ['VST', 2013],
#  ['DXC', 2013],
#  ['USFD', 2013],
#  ['CTLT', 2013],
#  ['STOR', 2013],
#  ['VOYA', 2013],
#  ['ATUS', 2013],
#  ['ZAYO', 2013],
#  ['QGEN', 2013],
#  ['CABO', 2013],
#  ['PRGO', 2013],
#  ['HUBS', 2013],
#  ['AMH', 2013],
#  ['HDS', 2013],
#  ['NRZ', 2013],
#  ['MDB', 2013],
#  ['PRAH', 2013],
#  ['PLNT', 2013],
#  ['ATH', 2013],
#  ['CDK', 2013],
#  ['ARW', 2013],
#  ['BRX', 2013],
#  ['W', 2013],
#  ['AXTA', 2013],
#  ['SABR', 2013],
#  ['AYX', 2013],
#  ['Z', 2013],
#  ['NTNX', 2013],
#  ['ETSY', 2013],
#  ['PEN', 2013],
#  ['PK', 2013],
#  ['MSG', 2013],
#  ['PE', 2013],
#  ['BLUE', 2013],
#  ['GRUB', 2013],
#  ['JBGS', 2013],
#  ['SERV', 2013],
#  ['GDI', 2013],
#  ['ASH', 2013],
#  ['PCTY', 2013],
#  ['BHF', 2013],
#  ['OUT', 2013],
#  ['PSTG', 2013],
#  ['VVV', 2013],
#  ['JHG', 2013],
#  ['MTCH', 2013],
#  ['CVNA', 2013],
#  ['FHB', 2013],
#  ['UNVR', 2013],
#  ['FND', 2013],
#  ['SAGE', 2013],
#  ['COTY', 2013],
#  ['CPA', 2013],
#  ['ENR', 2013],
#  ['FEYE', 2013],
#  ['NEWR', 2013],
#  ['AGIO', 2013],
#  ['AGR', 2013],
#  ['AA', 2013],
#  ['OLLI', 2013],
#  ['OMF', 2013],
#  ['PGRE', 2013],
#  ['HGV', 2013],
#  ['NAVI', 2013],
#  ['SC', 2013],
#  ['CC', 2013],
#  ['COMM', 2013],
#  ['ESRT', 2013],
#  ['PINC', 2013],
#  ['SFM', 2013],
#  ['PAG', 2013],
#  ['IGT', 2013],
#  ['AM', 2013],
#  ['SNDR', 2013],
#  ['TWOU', 2013],
#  ['SWCH', 2013],
#  ['VIRT', 2013],
#  ['CDEV', 2013],
#  ['AR', 2013],
#  ['ARD', 2013]]

# %%
income_statements_error
# Out:
# ['MSFT',
#  'JNJ',
#  'PG',
#  'MA',
#  'BAC',
#  'XOM',
#  'HD',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'BMY',
#  'COST',
#  'ACN',
#  'TMO',
#  'PM',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'LMT',
#  'SBUX',
#  'DHR',
#  'LOW',
#  'MMM',
#  'FIS',
#  'MO',
#  'MDLZ',
#  'CHTR',
#  'USB',
#  'GS',
#  'ADP',
#  'SYK',
#  'CB',
#  'UPS',
#  'CAT',
#  'PNC',
#  'ZTS',
#  'COP',
#  'NOW',
#  'AGN',
#  'CCI',
#  'GPN',
#  'CSX',
#  'NOC',
#  'APD',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'PGR',
#  'SHW',
#  'EXC',
#  'GD',
#  'EMR',
#  'AIG',
#  'EOG',
#  'EL',
#  'GM',
#  'SPG',
#  'ROST',
#  'PSX',
#  'DG',
#  'HCA',
#  'DD',
#  'ROP',
#  'AFL',
#  'BK',
#  'NEM',
#  'FDX',
#  'SYY',
#  'TRV',
#  'IR',
#  'PSA',
#  'F',
#  'HPQ',
#  'INFO',
#  'WEC',
#  'HLT',
#  'GIS',
#  'STZ',
#  'ED',
#  'REGN',
#  'AVB',
#  'PPG',
#  'STT',
#  'LULU',
#  'EBAY',
#  'PAYX',
#  'FE',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'DLR',
#  'ADM',
#  'TMUS',
#  'BLL',
#  'AWK',
#  'CTAS',
#  'ROK',
#  'PANW',
#  'MTB',
#  'AME',
#  'LYB',
#  'KR',
#  'VRSN',
#  'CMG',
#  'FAST',
#  'WY',
#  'DLTR',
#  'CLX',
#  'CDNS',
#  'SWKS',
#  'RCL',
#  'AEE',
#  'BBY',
#  'NTRS',
#  'DHI',
#  'MKC',
#  'VEEV',
#  'VMC',
#  'HPE',
#  'UAL',
#  'LEN',
#  'TFX',
#  'TRU',
#  'IAC',
#  'IP',
#  'MLM',
#  'DOV',
#  'TEAM',
#  'K',
#  'MKL',
#  'CINF',
#  'TIF',
#  'KMX',
#  'YUMC',
#  'HES',
#  'CAG',
#  'ULTA',
#  'XYL',
#  'TWLO',
#  'CAH',
#  'IFF',
#  'NUE',
#  'DRI',
#  'NLY',
#  'SSNC',
#  'LBRDK',
#  'UDR',
#  'GPC',
#  'BR',
#  'CBOE',
#  'ANET',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'SGEN',
#  'AMTD',
#  'CNP',
#  'EXAS',
#  'ODFL',
#  'ZBRA',
#  'ALNY',
#  'VAR',
#  'STE',
#  'TYL',
#  'EXPD',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'EPAM',
#  'RJF',
#  'SJM',
#  'MYL',
#  'NCLH',
#  'WST',
#  'FICO',
#  'LNC',
#  'Y',
#  'RE',
#  'NI',
#  'APA',
#  'HII',
#  'ROKU',
#  'BAH',
#  'WRK',
#  'CPT',
#  'AGNC',
#  'EMN',
#  'VER',
#  'DOX',
#  'ETFC',
#  'DISH',
#  'CHRW',
#  'SIRI',
#  'RPM',
#  'PKG',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'NNN',
#  'JBHT',
#  'RGA',
#  'NBIX',
#  'CSL',
#  'GGG',
#  'JLL',
#  'DVN',
#  'SNA',
#  'TTC',
#  'USFD',
#  'ON',
#  'SRPT',
#  'XPO',
#  'STOR',
#  'VOYA',
#  'ATUS',
#  'SCI',
#  'MASI',
#  'CPB',
#  'CZR',
#  'LAMR',
#  'HUBB',
#  'MPWR',
#  'TECH',
#  'GNTX',
#  'FFIV',
#  'CHE',
#  'PNR',
#  'PRGO',
#  'MOS',
#  'RGLD',
#  'HRC',
#  'BWA',
#  'CONE',
#  'DCI',
#  'OC',
#  'PVH',
#  'ATH',
#  'HZNP',
#  'WWD',
#  'FIVE',
#  'CW',
#  'MIDD',
#  'ACC',
#  'ITT',
#  'MKSI',
#  'CUZ',
#  'COG',
#  'CASY',
#  'BERY',
#  'ETSY',
#  'WSM',
#  'IDA',
#  'HOG',
#  'PRI',
#  'NYCB',
#  'ALSN',
#  'BRKR',
#  'AWI',
#  'HHC',
#  'HRB',
#  'PNFP',
#  'KEX',
#  'XEC',
#  'COR',
#  'THO',
#  'JWN',
#  'PSTG',
#  'PACW',
#  'VVV',
#  'TWO',
#  'JHG',
#  'STL',
#  'LOGM',
#  'CIM',
#  'RYN',
#  'UNVR',
#  'LOPE',
#  'IBKR',
#  'EXP',
#  'WRI',
#  'NFG',
#  'WTM',
#  'MIC',
#  'CPA',
#  'ASB',
#  'PBF',
#  'VMI',
#  'TRIP',
#  'ALKS',
#  'SIX',
#  'BOKF',
#  'RPAI',
#  'R',
#  'S',
#  'AN',
#  'TDS',
#  'CMD',
#  'OI',
#  'WWE',
#  'UFS',
#  'TCO',
#  'SATS',
#  'PINC',
#  'EQT',
#  'IGT',
#  'TFSL',
#  'SEB',
#  'SWCH',
#  'VIRT',
#  'USM',
#  'AR',
#  'ARD']

# %%
balance_sheets_error
# Out:
# ['MSFT',
#  'MA',
#  'BAC',
#  'XOM',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'BA',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'ABT',
#  'TMO',
#  'NEE',
#  'UNP',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'MMM',
#  'USB',
#  'GS',
#  'CI',
#  'CAT',
#  'SO',
#  'PNC',
#  'ZTS',
#  'COP',
#  'BLK',
#  'MS',
#  'CCI',
#  'GPN',
#  'ITW',
#  'NOC',
#  'TGT',
#  'AON',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'EXC',
#  'AIG',
#  'GM',
#  'PSX',
#  'KMI',
#  'ALL',
#  'PRU',
#  'BK',
#  'FDX',
#  'CTSH',
#  'TRV',
#  'PSA',
#  'F',
#  'GIS',
#  'ED',
#  'PPG',
#  'STT',
#  'EBAY',
#  'WLTW',
#  'PAYX',
#  'FE',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'DTE',
#  'CTAS',
#  'MSCI',
#  'DFS',
#  'ROK',
#  'IDXX',
#  'PANW',
#  'MTB',
#  'AME',
#  'CMG',
#  'WY',
#  'SWKS',
#  'AEE',
#  'NTRS',
#  'MKC',
#  'VEEV',
#  'AJG',
#  'TRU',
#  'IAC',
#  'IP',
#  'K',
#  'HES',
#  'CAG',
#  'ULTA',
#  'PFG',
#  'IFF',
#  'HBAN',
#  'DRI',
#  'GRMN',
#  'NLY',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'AMTD',
#  'EXAS',
#  'ODFL',
#  'HRL',
#  'TYL',
#  'MKTX',
#  'ELS',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'RJF',
#  'NCLH',
#  'WST',
#  'VMW',
#  'APA',
#  'HII',
#  'ROKU',
#  'BAH',
#  'WRK',
#  'EMN',
#  'CCK',
#  'ETFC',
#  'RPM',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'RGA',
#  'ON',
#  'SCI',
#  'AFG',
#  'HUBB',
#  'KIM',
#  'MPWR',
#  'GNTX',
#  'LPLA',
#  'CHE',
#  'MOS',
#  'BWA',
#  'PBCT',
#  'RHI',
#  'SPR',
#  'CONE',
#  'TCF',
#  'HFC',
#  'FIVE',
#  'CW',
#  'COG',
#  'BERY',
#  'ETSY',
#  'WSM',
#  'IDA',
#  'BPOP',
#  'ROL',
#  'NYCB',
#  'FHN',
#  'PNFP',
#  'LAZ',
#  'STL',
#  'LOGM',
#  'ERIE',
#  'FHB',
#  'CIM',
#  'IBKR',
#  'ICUI',
#  'WTFC',
#  'BOH',
#  'GRA',
#  'RBC',
#  'MIC',
#  'CPA',
#  'SCCO',
#  'PBF',
#  'EVR',
#  'FLR',
#  'BOKF',
#  'SPB',
#  'TDS',
#  'TCO',
#  'BGCP',
#  'PAG',
#  'TFSL',
#  'ANAT',
#  'USM',
#  'AR',
#  'ARD']

# %%
cash_flows_error
# Out:
# ['MSFT',
#  'MA',
#  'BAC',
#  'XOM',
#  'MRK',
#  'CVX',
#  'PEP',
#  'CMCSA',
#  'WFC',
#  'C',
#  'WMT',
#  'MDT',
#  'MCD',
#  'ABT',
#  'IBM',
#  'ACN',
#  'TMO',
#  'NEE',
#  'ABBV',
#  'HON',
#  'UTX',
#  'NKE',
#  'AVGO',
#  'ORCL',
#  'GE',
#  'MMM',
#  'GILD',
#  'USB',
#  'ADP',
#  'UPS',
#  'CAT',
#  'SO',
#  'D',
#  'PNC',
#  'ZTS',
#  'COP',
#  'CCI',
#  'GPN',
#  'ITW',
#  'CSX',
#  'DE',
#  'ECL',
#  'AEP',
#  'KMB',
#  'SLB',
#  'SHW',
#  'EXC',
#  'AIG',
#  'PSX',
#  'KMI',
#  'BK',
#  'NEM',
#  'FDX',
#  'SYY',
#  'TRV',
#  'PSA',
#  'F',
#  'GIS',
#  'ED',
#  'APH',
#  'PPG',
#  'ES',
#  'STT',
#  'EBAY',
#  'PAYX',
#  'FE',
#  'FLT',
#  'PH',
#  'LUV',
#  'SQ',
#  'A',
#  'PPL',
#  'WMB',
#  'CTAS',
#  'ROK',
#  'IDXX',
#  'PANW',
#  'MTB',
#  'AME',
#  'LYB',
#  'ALXN',
#  'CMG',
#  'WY',
#  'SWKS',
#  'AEE',
#  'NTRS',
#  'MKC',
#  'VEEV',
#  'VMC',
#  'HPE',
#  'AJG',
#  'UAL',
#  'CHD',
#  'TRU',
#  'IAC',
#  'ACGL',
#  'IP',
#  'MLM',
#  'K',
#  'HES',
#  'CAG',
#  'ULTA',
#  'XYL',
#  'TWLO',
#  'IFF',
#  'DRI',
#  'NLY',
#  'UDR',
#  'CBOE',
#  'ANET',
#  'GWW',
#  'FOXA',
#  'OKTA',
#  'AMTD',
#  'CNP',
#  'EXAS',
#  'ODFL',
#  'FNF',
#  'TYL',
#  'ALLY',
#  'ALLE',
#  'FANG',
#  'ARNC',
#  'SJM',
#  'MYL',
#  'NCLH',
#  'WST',
#  'VNO',
#  'NI',
#  'BRO',
#  'APA',
#  'BAH',
#  'WRK',
#  'VER',
#  'DOX',
#  'CCK',
#  'ETFC',
#  'RPM',
#  'BFAM',
#  'ZEN',
#  'GLPI',
#  'RGA',
#  'SNA',
#  'ON',
#  'XPO',
#  'STOR',
#  'VOYA',
#  'ATUS',
#  'SCI',
#  'AIZ',
#  'AFG',
#  'DVA',
#  'HUBB',
#  'KIM',
#  'MPWR',
#  'GNTX',
#  'CHE',
#  'MOS',
#  'HRC',
#  'BWA',
#  'CONE',
#  'HFC',
#  'FIVE',
#  'AOS',
#  'COG',
#  'BERY',
#  'ETSY',
#  'LB',
#  'NYT',
#  'WAL',
#  'PRI',
#  'HHC',
#  'PNFP',
#  'COR',
#  'STL',
#  'LOGM',
#  'UMPQ',
#  'WTM',
#  'RBC',
#  'MIC',
#  'CPA',
#  'SCCO',
#  'ASB',
#  'PBF',
#  'TRIP',
#  'SIX',
#  'COLM',
#  'OMF',
#  'PGRE',
#  'BDN',
#  'HGV',
#  'FLR',
#  'BOKF',
#  'TDS',
#  'OI',
#  'UFS',
#  'TCO',
#  'EQT',
#  'IGT',
#  'SEB',
#  'SWCH',
#  'VIRT',
#  'USM',
#  'AR',
#  'ARD']

# %%
# cash_flows.reports[1]

# %%
# cash_flows.reports[0]
