# %%
from bs4 import BeautifulSoup
import re
from sec_edgar_downloader import Downloader
import pandas as pd
from os import listdir
from os.path import isfile, join, isdir
import csv

# %%
# Load the company ticker list

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-04bb23a834bb> in <module>
#       1 # Load the company ticker list
#       2
# ----> 3 df.head()
#
# NameError: name 'df' is not defined

# %%
# set the location where all the downloaded filings will be saved
downloadPath = "../../"
dl = Downloader(downloadPath)

# %%
# Download 10 latest 10-K filings for the given company ticker
def downloadFilings(ticker, filing_type="10-K", latest=10):
    dl.get(filing_type, ticker, latest)
downloadFilings("BRK")

# %%
pos_dat = None
document = {}
itemStartEndMapping = {"item1":"item1a","item1a":"item1b","item1b":"item2", "item2":"item3","item3":"item4","item4":"item5",
                      "item5":"item6", "item6":"item7","item7":"item7a","item7a":"item8", "item8":"item9","item9":"item9a",
                       "item9a":"item9b","item9b":"item10","item10":"item11","item11":"item12","item12":"item13",
                       "item13":"item14","item14":"item15","item15":"item16"}
def extractHTMLSections(raw_10k):
    
    global pos_dat
    # Regex to find <DOCUMENT> tags
    doc_start_pattern = re.compile(r'<DOCUMENT>')
    doc_end_pattern = re.compile(r'</DOCUMENT>')
    
    # Regex to find <TYPE> tag prceeding any characters, terminating at new line
    type_pattern = re.compile(r'<TYPE>[^\n]+')
    
    # Create 3 lists with the span idices for each regex
    
    ### There are many <Document> Tags in this text file, each as specific exhibit like 10-K, EX-10.17 etc
    ### First filter will give us document tag start <end> and document tag end's <start> 
    ### We will use this to later grab content in between these tags
    doc_start_is = [x.end() for x in doc_start_pattern.finditer(raw_10k)]
    doc_end_is = [x.start() for x in doc_end_pattern.finditer(raw_10k)]

    ### Type filter is interesting, it looks for <TYPE> with Not flag as new line, ie terminare there, with + sign
    ### to look for any char afterwards until new line \n. This will give us <TYPE> followed Section Name like '10-K'
    ### Once we have have this, it returns String Array, below line will with find content after <TYPE> ie, '10-K' 
    ### as section names
    doc_types = [x[len('<TYPE>'):] for x in type_pattern.findall(raw_10k)]

    # Create a loop to go through each section type and save only the 10-K section in the dictionary
    for doc_type, doc_start, doc_end in zip(doc_types, doc_start_is, doc_end_is):
        if doc_type == '10-K':
            document[doc_type] = raw_10k[doc_start:doc_end]
    
    # Write the regex to get different sections from the 10-K
    regex = re.compile(r'(>Item(\s|&#160;RIS|&nbsp;)(1A|6|1B|7A|7|8)\.{0,1})|(ITEM\s(1A|6|1B|7A|7|8))')
    
    # Use finditer to math the regex
    matches = regex.finditer(document['10-K'])
    
    # Create the dataframe
    test_df = pd.DataFrame([(x.group(), x.start(), x.end()) for x in matches])

    test_df.columns = ['item', 'start', 'end']
    test_df['item'] = test_df.item.str.lower()
    
    # Get rid of unnesesary charcters from the dataframe
    test_df.replace('&#160;',' ',regex=True,inplace=True)
    test_df.replace('&nbsp;',' ',regex=True,inplace=True)
    test_df.replace(' ','',regex=True,inplace=True)
    test_df.replace('\.','',regex=True,inplace=True)
    test_df.replace('>','',regex=True,inplace=True)
    
    # Aggregate the different parts of the sane section
    pos_dat = test_df.groupby(['item']).agg({'start': 'min', 'end': 'max'})
    print("Sections Extracted:{}".format(list(pos_dat.index)))
#     print("send any section name as printed")
    return list(pos_dat.index)

def extractTextFromSection(key, document_type = "10-K"):
    global pos_dat
    if key in list(pos_dat.index):
        if document_type not in document:
            print("{} not found".format(document_type))
            # Get Item 1a
        else:
            end = ""
            while True:
                if key not in itemStartEndMapping.keys():
                    break
                elif itemStartEndMapping[key] not in list(pos_dat.index):
                    key = itemStartEndMapping[key]
                else:
                    end = itemStartEndMapping[key]
                    break
            if len(end) == "0":
                print("Error Cannnot find End tag for {}".format(key))
                return
            else:                
                item_raw = document['10-K'][pos_dat['start'].loc[key]:pos_dat['start'].loc[end]]
                item_raw_content = BeautifulSoup(item_raw, "lxml")
                content = item_raw_content.get_text()
                content.replace('\n',' ')
                content.replace('  ',' ')
                content = re.sub('\s+',' ',content)
                return content
    else:
        print("{} not found".format(key))
        return ""

# %%
## Get List of all the folders concatenated with its relative path
companyLessthan10 = []
companyWithNoData = []
## SEC-Edgar module creates a folder 'sec_edgar_filings' in which it downloades the filings
newPath = downloadPath + "sec_edgar_filings"
companyFilingsPath = ""
erroneousCompanies = []
## loop through all folders i.e. companies
with open('../../writeData.csv', mode='w+', encoding="utf-8", newline='') as file:
    fieldnames = ['Ticker', "Company Name", "Industry","Top 100","Year","Risk Factors"]
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()
    for index, row in df.iterrows():
        try:
            ## Download latest 10 filings for the Company
            latest = 10
            print("Downloading {} latest Filings for {}".format(latest, row["Company Name"]))
            downloadFilings(ticker=row['Ticker'], latest = 10)

            ## SEC-Edgar module creates a subfolder named by the company ticker inside 'sec_edgar_filings'
            # Therfore join the path 
            companyFilingsPath = join(newPath, row['Ticker'], "10-K")
            print("companyfilingsPath {}".format(companyFilingsPath))

            ## Sanity Check: if the files are downloaded
            if not isdir(companyFilingsPath):
                print("No filings Downloaded for {}".format(row["Company Name"]))
                companyWithNoData.append(row["Company Name"])
                continue
            # List downloded filing path and file names
            companyFilings = [(join(companyFilingsPath, f), f) for f in listdir(companyFilingsPath)]

            ## Log the companies having less than 10 recent filings
            if len(companyFilings) <10:
                companyLessthan10.append(row["Company Name"])

            # Extract Section from each filings
            for filing in companyFilings:

                # Get filing path and filing path
                filingPath, filingName = filing

                f = open(filingPath,'r')
                textdata = f.read()
                f.close()
                sectionList = extractHTMLSections(textdata)
                text = ""
                ## Extracting Risk FActors Section Item 1A
                if "item1a" in sectionList:
                    text = extractTextFromSection(key ="item1a")
                print("Extracted Text Length:{}".format(len(text)))

                # Get year of the filling from the filing name
                # file name ex "0001283630-16-000038.txt", 2016 represents year in which 10k was filed and it was of 2015
                filingName = filingName.split("-")
                ['Ticker', "Company Name", "Industry","Top 100","Year","Risk Factors"]
                #way to write to csv file
                writer.writerow({"Ticker":row['Ticker'], "Company Name":row["Company Name"],"Industry": row["Industry"],"Top 100":row["Top 100"], "Year":int(filingName[1])-1 +2000,"Risk Factors":text})
        except Exception as e:
            erroneousCompanies.append((e, row["Company Name"]))
            print("Exception {} Occured for {}, skipping".format(e,row["Company Name"]))
# Out:
# Downloading 10 latest Filings for Apple Inc.
# companyfilingsPath ../../sec_edgar_filings\AAPL\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:51353
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:50930
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:48539
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Downloading 10 latest Filings for Microsoft Corporation
# companyfilingsPath ../../sec_edgar_filings\MSFT\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:47856
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:57881
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:59521
# Downloading 10 latest Filings for Amazon.com, Inc.
# companyfilingsPath ../../sec_edgar_filings\AMZN\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Downloading 10 latest Filings for Facebook, Inc. Class A
# companyfilingsPath ../../sec_edgar_filings\FB\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for Berkshire Hathaway Inc. Class B
# companyfilingsPath ../../sec_edgar_filings\BRK.B\10-K
# No filings Downloaded for Berkshire Hathaway Inc. Class B
# Downloading 10 latest Filings for Alphabet Inc. Class A
# companyfilingsPath ../../sec_edgar_filings\GOOGL\10-K
# Sections Extracted:['item7']
# Extracted Text Length:0
# Sections Extracted:['item7']
# Extracted Text Length:0
# Sections Extracted:['item7']
# Extracted Text Length:0
# Sections Extracted:['item7']
# Extracted Text Length:0
# Sections Extracted:['item7', 'item8']
# Extracted Text Length:0
# Downloading 10 latest Filings for JPMorgan Chase & Co.
# companyfilingsPath ../../sec_edgar_filings\JPM\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:66112
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:82719
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:57909
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:59629
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:67319
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:27
# Downloading 10 latest Filings for Johnson & Johnson
# companyfilingsPath ../../sec_edgar_filings\JNJ\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:237
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:237
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:544
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:530
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23339
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24183
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26100
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:27055
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Johnson & Johnson, skipping
# Downloading 10 latest Filings for Visa Inc. Class A
# companyfilingsPath ../../sec_edgar_filings\V\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item\n1a', 'item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Downloading 10 latest Filings for Procter & Gamble Company
# companyfilingsPath ../../sec_edgar_filings\PG\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Procter & Gamble Company, skipping
# Downloading 10 latest Filings for Intel Corporation
# companyfilingsPath ../../sec_edgar_filings\INTC\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:34400
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:37959
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:38106
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:41963
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:32
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:32
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Intel Corporation, skipping
# Downloading 10 latest Filings for Mastercard Incorporated Class A
# companyfilingsPath ../../sec_edgar_filings\MA\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for Bank of America Corp
# companyfilingsPath ../../sec_edgar_filings\BAC\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Downloading 10 latest Filings for UnitedHealth Group Incorporated
# companyfilingsPath ../../sec_edgar_filings\UNH\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for AT&T Inc.
# companyfilingsPath ../../sec_edgar_filings\T\10-K
# Sections Extracted:['item1a', 'item6', 'item7', 'item7a', 'item8']
# Exception 'item5' Occured for AT&T Inc., skipping
# Downloading 10 latest Filings for Exxon Mobil Corporation
# companyfilingsPath ../../sec_edgar_filings\XOM\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item\n7', 'item\n8', 'item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Downloading 10 latest Filings for Home Depot, Inc.
# companyfilingsPath ../../sec_edgar_filings\HD\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Home Depot, Inc., skipping
# Downloading 10 latest Filings for Walt Disney Company
# companyfilingsPath ../../sec_edgar_filings\DIS\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for Verizon Communications Inc.
# companyfilingsPath ../../sec_edgar_filings\VZ\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Verizon Communications Inc., skipping
# Downloading 10 latest Filings for Coca-Cola Company
# companyfilingsPath ../../sec_edgar_filings\KO\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:50875
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:49165
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:52721
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:56179
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:62600
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:64529
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:62149
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:69366
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75192
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for Merck & Co., Inc.
# companyfilingsPath ../../sec_edgar_filings\MRK\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:75
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Merck & Co., Inc., skipping
# Downloading 10 latest Filings for Pfizer Inc.
# companyfilingsPath ../../sec_edgar_filings\PFE\10-K
# Sections Extracted:['item1a']
# Exception 'item16' Occured for Pfizer Inc., skipping
# Downloading 10 latest Filings for Chevron Corporation
# companyfilingsPath ../../sec_edgar_filings\CVX\10-K
# Sections Extracted:['item1a', 'item6', 'item7', 'item7a', 'item8']
# Exception 'item5' Occured for Chevron Corporation, skipping
# Downloading 10 latest Filings for Cisco Systems, Inc.
# companyfilingsPath ../../sec_edgar_filings\CSCO\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Cisco Systems, Inc., skipping
# Downloading 10 latest Filings for PepsiCo, Inc.
# companyfilingsPath ../../sec_edgar_filings\PEP\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for PepsiCo, Inc., skipping
# Downloading 10 latest Filings for Comcast Corporation Class A
# companyfilingsPath ../../sec_edgar_filings\CMCSA\10-K
# Sections Extracted:['item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Downloading 10 latest Filings for Wells Fargo & Company
# companyfilingsPath ../../sec_edgar_filings\WFC\10-K
# Sections Extracted:['item\n1a', 'item\n6', 'item\n8', 'item1b', 'item7', 'item7a']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:250
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Wells Fargo & Company, skipping
# Downloading 10 latest Filings for Adobe Inc.
# companyfilingsPath ../../sec_edgar_filings\ADBE\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Adobe Inc., skipping
# Downloading 10 latest Filings for Boeing Company
# companyfilingsPath ../../sec_edgar_filings\BA\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Boeing Company, skipping
# Downloading 10 latest Filings for Citigroup Inc.
# companyfilingsPath ../../sec_edgar_filings\C\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Citigroup Inc., skipping
# Downloading 10 latest Filings for Walmart Inc.
# companyfilingsPath ../../sec_edgar_filings\WMT\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Walmart Inc., skipping
# Downloading 10 latest Filings for Medtronic Plc
# companyfilingsPath ../../sec_edgar_filings\MDT\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:88517
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:88659
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:93637
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:61621
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:62167
# Downloading 10 latest Filings for McDonald's Corporation
# companyfilingsPath ../../sec_edgar_filings\MCD\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for McDonald's Corporation, skipping
# Downloading 10 latest Filings for Netflix, Inc.
# companyfilingsPath ../../sec_edgar_filings\NFLX\10-K
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:48041
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:45123
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:46984
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:55991
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:59154
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:63434
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:48470
# Downloading 10 latest Filings for Abbott Laboratories
# companyfilingsPath ../../sec_edgar_filings\ABT\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:20062
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:21610
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24809
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24329
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25367
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item8']
# Extracted Text Length:26400
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:28463
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25624
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26335
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26142
# Downloading 10 latest Filings for salesforce.com, inc.
# companyfilingsPath ../../sec_edgar_filings\CRM\10-K
# Sections Extracted:['item1a', 'item6', 'item7', 'item7a', 'item8']
# Exception 'item5' Occured for salesforce.com, inc., skipping
# Downloading 10 latest Filings for Bristol-Myers Squibb Company
# companyfilingsPath ../../sec_edgar_filings\BMY\10-K
# Sections Extracted:['item8']
# Extracted Text Length:0
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Bristol-Myers Squibb Company, skipping
# Downloading 10 latest Filings for NVIDIA Corporation
# companyfilingsPath ../../sec_edgar_filings\NVDA\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for PayPal Holdings Inc
# companyfilingsPath ../../sec_edgar_filings\PYPL\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for Amgen Inc.
# companyfilingsPath ../../sec_edgar_filings\AMGN\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Amgen Inc., skipping
# Downloading 10 latest Filings for International Business Machines Corporation
# companyfilingsPath ../../sec_edgar_filings\IBM\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Downloading 10 latest Filings for Costco Wholesale Corporation
# companyfilingsPath ../../sec_edgar_filings\COST\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Downloading 10 latest Filings for Accenture Plc Class A
# companyfilingsPath ../../sec_edgar_filings\ACN\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Sections Extracted:['item8']
# Extracted Text Length:0
# Downloading 10 latest Filings for Thermo Fisher Scientific Inc.
# companyfilingsPath ../../sec_edgar_filings\TMO\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Thermo Fisher Scientific Inc., skipping
# Downloading 10 latest Filings for Philip Morris International Inc.
# companyfilingsPath ../../sec_edgar_filings\PM\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:18963
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:19078
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:19784
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:20435
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:20404
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:21456
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23827
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26222
# Downloading 10 latest Filings for NextEra Energy, Inc.
# companyfilingsPath ../../sec_edgar_filings\NEE\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for Union Pacific Corporation
# companyfilingsPath ../../sec_edgar_filings\UNP\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for AbbVie, Inc.
# companyfilingsPath ../../sec_edgar_filings\ABBV\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:80
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a']
# Extracted Text Length:58219
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:52564
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:47899
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for Honeywell International Inc.
# companyfilingsPath ../../sec_edgar_filings\HON\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:33354
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Honeywell International Inc., skipping
# Downloading 10 latest Filings for United Technologies Corporation
# companyfilingsPath ../../sec_edgar_filings\UTX\10-K
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for Eli Lilly and Company
# companyfilingsPath ../../sec_edgar_filings\LLY\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:15269
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:21210
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:13687
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:14275
# Downloading 10 latest Filings for Texas Instruments Incorporated
# companyfilingsPath ../../sec_edgar_filings\TXN\10-K
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24047
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:16714
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a']
# Extracted Text Length:23854
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22995
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24087
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24539
# Downloading 10 latest Filings for NIKE, Inc. Class B
# companyfilingsPath ../../sec_edgar_filings\NKE\10-K
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:69579
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item6', 'item7', 'item8']
# Extracted Text Length:0
# Downloading 10 latest Filings for Broadcom Inc.
# companyfilingsPath ../../sec_edgar_filings\AVGO\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:22
# Downloading 10 latest Filings for Linde plc
# companyfilingsPath ../../sec_edgar_filings\LIN\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:29039
# Sections Extracted:['item1b', 'item6']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:28911
# Downloading 10 latest Filings for Oracle Corporation
# companyfilingsPath ../../sec_edgar_filings\ORCL\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item\n8', 'item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for General Electric Company
# companyfilingsPath ../../sec_edgar_filings\GE\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:31
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:31
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:31
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:30
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:28
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:28
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for Lockheed Martin Corporation
# companyfilingsPath ../../sec_edgar_filings\LMT\10-K
# Exception Length mismatch: Expected axis has 0 elements, new values have 3 elements Occured for Lockheed Martin Corporation, skipping
# Downloading 10 latest Filings for Tesla Inc
# companyfilingsPath ../../sec_edgar_filings\TSLA\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for QUALCOMM Incorporated
# companyfilingsPath ../../sec_edgar_filings\QCOM\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Downloading 10 latest Filings for American Tower Corporation
# companyfilingsPath ../../sec_edgar_filings\AMT\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:21
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:21
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:22
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:21
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:21
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7']
# Extracted Text Length:25
# Sections Extracted:['item1b', 'item6', 'item7']
# Extracted Text Length:0
# Downloading 10 latest Filings for Starbucks Corporation
# companyfilingsPath ../../sec_edgar_filings\SBUX\10-K
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:25
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Downloading 10 latest Filings for Danaher Corporation
# companyfilingsPath ../../sec_edgar_filings\DHR\10-K
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:0
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:26
# Downloading 10 latest Filings for Lowe's Companies, Inc.
# companyfilingsPath ../../sec_edgar_filings\LOW\10-K
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:28
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:15609
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:16710
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:17366
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:24
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Sections Extracted:['item1a', 'item1b', 'item6', 'item7', 'item7a', 'item8']
# Extracted Text Length:23
# Downloading 10 latest Filings for CVS Health Corporation
# companyfilingsPath ../../sec_edgar_filings\CVS\10-K
# ...
# Downloading 10 latest Filings for Host Hotels & Resorts, Inc.
# Exception [Errno 28] No space left on device Occured for Host Hotels & Resorts, Inc., skipping
# Downloading 10 latest Filings for Arconic, Inc.
# Exception [Errno 28] No space left on device Occured for Arconic, Inc., skipping
# Downloading 10 latest Filings for EPAM Systems, Inc.
# Exception [Errno 28] No space left on device Occured for EPAM Systems, Inc., skipping
# Downloading 10 latest Filings for Raymond James Financial, Inc.
# Exception [Errno 28] No space left on device Occured for Raymond James Financial, Inc., skipping
# Downloading 10 latest Filings for Teradyne, Inc.
# Exception [Errno 28] No space left on device Occured for Teradyne, Inc., skipping
# Downloading 10 latest Filings for Brown-Forman Corporation Class B
# companyfilingsPath ../../sec_edgar_filings\BF.B\10-K
# No filings Downloaded for Brown-Forman Corporation Class B
# Downloading 10 latest Filings for J.M. Smucker Company
# Exception [Errno 28] No space left on device Occured for J.M. Smucker Company, skipping
# Downloading 10 latest Filings for Mylan N.V.
# Exception [Errno 28] No space left on device Occured for Mylan N.V., skipping
# Downloading 10 latest Filings for Textron Inc.
# Exception [Errno 28] No space left on device Occured for Textron Inc., skipping
# Downloading 10 latest Filings for GoDaddy, Inc. Class A
# Exception [Errno 28] No space left on device Occured for GoDaddy, Inc. Class A, skipping
# Downloading 10 latest Filings for Western Union Company
# Exception [Errno 28] No space left on device Occured for Western Union Company, skipping
# Downloading 10 latest Filings for Avery Dennison Corporation
